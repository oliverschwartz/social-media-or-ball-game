# %%
import os
import networkx as nx
import matplotlib.pyplot as plt
import csv
# %matplotlib inline

# %%
# create digraph
G = nx.DiGraph()

# %%
# add a node for each player
os.chdir("../processed")
for file in os.listdir():
    if file is not "username"
    G.add_node(file)

# %%
# for every player, add directed edges to players they follow
for file in os.listdir():
    with open(file, 'r') as f:
        reader = csv.reader(f)
        for line in reader:
            #G.add_edge(file, line)
# Out:
# ['username']
# 3tross1.csv
# ['emmaroberts']
# 3tross1.csv
# ['bryceharper3']
# 3tross1.csv
# ['micahfraction']
# 3tross1.csv
# ['sharkaddicts2']
# 3tross1.csv
# ['juansharks']
# 3tross1.csv
# ['robliefeld']
# 3tross1.csv
# ['f1']
# 3tross1.csv
# ['dk_metcalf14']
# 3tross1.csv
# ['nigelwg5']
# 3tross1.csv
# ['justinpomar']
# 3tross1.csv
# ['milt_p']
# 3tross1.csv
# ['funnyblacks']
# 3tross1.csv
# ['cinephile.club']
# 3tross1.csv
# ['thescenesofcinema']
# 3tross1.csv
# ['animationv']
# 3tross1.csv
# ['carz_hype']
# 3tross1.csv
# ['dollydoozie']
# 3tross1.csv
# ['twoshotonee']
# 3tross1.csv
# ['dominicslegion']
# 3tross1.csv
# ['_justinmulford']
# 3tross1.csv
# ['alharrington3']
# 3tross1.csv
# ['bqquinn']
# 3tross1.csv
# ['holtonanthony']
# 3tross1.csv
# ['mholtonjr']
# 3tross1.csv
# ['horrorfeels']
# 3tross1.csv
# ['cheddar']
# 3tross1.csv
# ['outdoorskie']
# 3tross1.csv
# ['chadsmithofficial']
# 3tross1.csv
# ['richardpettymotorsports']
# 3tross1.csv
# ['weirdvidz']
# 3tross1.csv
# ...

# %%
G.adj
# Out:
# AdjacencyView({'3tross1.csv': {}, 'danilogallogallinari.csv': {}, 'stevenadams.csv': {}, '_alvo_.csv': {}, 'traeyoung.csv': {}, '1ngram4.csv': {}, 'mr_carter5.csv': {}, 'iclark21.csv': {}, 'thats_g_.csv': {}, 'austinjrivers.csv': {}, 'dubblea74.csv': {}, 'mkg14.csv': {}, 'ccapela15.csv': {}, 'andre.csv': {}, 'jaytatum0.csv': {}, 'the_4th_holiday.csv': {}, 'juliusrandle30.csv': {}, 'ygtrece.csv': {}, 'demar_derozan.csv': {}, 'abrooksart.csv': {}, 'drewroc5.csv': {}, 'brandonknight.csv': {}, 'deandreayton.csv': {}, 'itsaverybradley.csv': {}, 'joeingles7.csv': {}, 'alexlen_21.csv': {}, 'stephencurry30.csv': {}, 'nicbatum88.csv': {}, 'andersonvarejao18.csv': {}, 'alantwilliams.csv': {}, 'lukadoncic.csv': {}, 'kuz.csv': {}, 'amilejefferson.csv': {}, '22wiggins.csv': {}, 'kyle_lowry7.csv': {}, 'bogdanbogdanovic.csv': {}, 'thonmaker.csv': {}, 'antsimons.csv': {}, 'benoudrih19.csv': {}, 'antezizic.csv': {}, 'giannis_an34.csv': {}, 'twoshotonee.csv': {}, 'chrisbosh.csv': {}, 'iammontaellis.cs
# ...

# %%
print(G)
