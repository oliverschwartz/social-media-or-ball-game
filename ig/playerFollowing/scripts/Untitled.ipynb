# %%
# dependencies and constants
import os, csv
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
FILE_EXT_NUM = -14
FILE_EXT     = "_processed.csv"
DIR          = "../processed"

# %%
# create digraph
G = nx.DiGraph()

# %%
# add a node for each player
os.chdir(DIR)
for file in os.listdir():
    if file[-14:] == FILE_EXT: # ignore hidden files
        G.add_node(file[:FILE_EXT_NUM])

# %%
# add directed edges between players
for node in G.adj:
    with open(str(node + FILE_EXT), 'r') as file:
        for line in file.readlines():
            line = line.strip()
            for player in G.adj:
                if player == line and player != node:
                    G.add_edge(node, line)

# %%
# print graph
nx.draw_networkx(G, with_labels=False, node_size=10)
plt.draw()
plt.show()

# %%
print(G.edges)
# Out:
# [('kennethfaried35', 'ccapela15'), ('kennethfaried35', 'brandonknight'), ('kennethfaried35', 'austinjrivers'), ('kennethfaried35', 'youngheirgordon'), ('kennethfaried35', 'cp3'), ('kennethfaried35', 'allencrabbe'), ('kennethfaried35', 'alantwilliams'), ('kennethfaried35', 'dloading'), ('kennethfaried35', 'stephencurry30'), ('kennethfaried35', 'kostas__ante13'), ('kennethfaried35', 'iclark21'), ('kennethfaried35', 'ageefla'), ('kennethfaried35', 'thats_g_'), ('kennethfaried35', 'klaythompson'), ('kennethfaried35', 'andredrummondd'), ('kennethfaried35', 'jharden13'), ('kennethfaried35', 'bradbeal3'), ('kennethfaried35', 'demar_derozan'), ('kennethfaried35', 'ygtrece'), ('kennethfaried35', 'mac11'), ('kennethfaried35', 'danilogallogallinari'), ('kennethfaried35', 'damianlillard'), ('flydre21', 'dulenader2'), ('flydre21', 'dloading'), ('flydre21', 'zachlavine8'), ('flydre21', 'carmeloanthony'), ('flydre21', 'stevenadams'), ('flydre21', 'alexabrines'), ('flydre21', 'acfresh21'), ('flydre21', 'eneskanter11'), ('flydre21', 'dbook'), ('flydre21', 'dakarijohnson'), ('flydre21', 'deandre'), ('flydre21', '3tross1'), ('flydre21', 'vevey1800'), ('flydre21', 'sergeibaka'), ('flydre21', 'ygtrece'), ('sdot1414', '_alvo_'), ('sdot1414', 'andre'), ('sdot1414', 'klaythompson'), ('sdot1414', 'iclark21'), ('sdot1414', 'stephencurry30'), ('demar_derozan', 'bradbeal3'), ('demar_derozan', '_alvo_'), ('demar_derozan', 'sergeibaka'), ('demar_derozan', 'kingjames'), ('demar_derozan', 'carmeloanthony'), ('demar_derozan', 'chrisbosh'), ('demar_derozan', 'stephencurry30'), ('demar_derozan', 'antdavis23'), ('demar_derozan', 'kyle_lowry7'), ('demar_derozan', '3tross1'), ('demar_derozan', 'damianlillard'), ('demar_derozan', 'ygtrece'), ('demar_derozan', 'iamamirjohnson'), ('demar_derozan', 'jharden13'), ('jlin7', 'sergeibaka'), ('jlin7', 'alexthegreat22'), ('jlin7', 'alexlen_21'), ('jlin7', 'traeyoung'), ('jlin7', 'brandonknight'), ('jlin7', 'dloading'), ('jlin7', 'stephencurry30'), ('jlin7', 'omricasspi18'), ('jlin7', 'jharden13'), ('iammontaellis', 'youngheirgordon'), ('iammontaellis', '22wiggins'), ('iammontaellis', 'klaythompson'), ('iammontaellis', 'damianlillard'), ('iammontaellis', 'zachlavine8'), ('iammontaellis', 'karltowns'), ('iammontaellis', 'rajonrondo'), ('iammontaellis', 'kyle_lowry7'), ('iammontaellis', 'chrisbosh'), ('iammontaellis', 'dloading'), ('iammontaellis', 'cp3'), ('iammontaellis', 'carmeloanthony'), ('iammontaellis', 'demar_derozan'), ('iammontaellis', 'isaiahthomas'), ('iammontaellis', 'kingjames'), ('iammontaellis', 'deandre'), ('iammontaellis', 'antdavis23'), ('iammontaellis', 'jimmybutler'), ('iammontaellis', 'blakegriffin23'), ('iammontaellis', 'jharden13'), ('iammontaellis', 'stephencurry30'), ('iammontaellis', 'ygtrece'), ('dbook', 'kuz'), ('dbook', 'deandreayton'), ('dbook', 'bradbeal3'), ('dbook', 'jharden13'), ('dbook', 'ygtrece'), ('dbook', 'traeyoung'), ('dbook', 'brandonknight'), ('dbook', 'alantwilliams'), ('dbook', 'jaytatum0'), ('dbook', 'alexlen_21'), ('dbook', 'cp3'), ('dbook', 'dakarijohnson'), ('dbook', 'alexthegreat22'), ('dbook', 'drewroc5'), ('dbook', 'danilogallogallinari'), ('dbook', 'antdavis23'), ('dbook', 'karltowns'), ('dbook', 'andre'), ('dbook', 'dloading'), ('antsimons', 'chiefhasarrived'), ('antsimons', 'the_4th_holiday'), ('antsimons', 'damianlillard'), ('antsimons', 'rajonrondo'), ('antsimons', 'jaytatum0'), ('antsimons', 'bensimmons'), ('antsimons', '1ngram4'), ('antsimons', 'dloading'), ('antsimons', 'ygtrece'), ('antsimons', 'jharden13'), ('antsimons', 'kingjames'), ('antsimons', 'antdavis23'), ('antsimons', 'austinjrivers'), ('giannis_an34', 'thonmaker'), ('giannis_an34', 'kostas__ante13'), ('giannis_an34', 'mr_carter5'), ('sergeibaka', 'jharden13'), ('sergeibaka', 'demar_derozan'), ('sergeibaka', 'vevey1800'), ('andersonvarejao18', 'omricasspi18'), ('andersonvarejao18', 'kingjames'), ('andersonvarejao18', 'klaythompson'), ('andersonvarejao18', 'iclark21'), ('andersonvarejao18', 'sdot1414'), ('a ...
